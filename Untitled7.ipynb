# %%
import pandas as pd

# %%
# importing the dataset
data=pd.read_csv("data.csv")

# %%
data
# Out:
#     student_id  age  gender        course_type  session_count  \
# 0        S0001   24    Male              UI/UX             11
# 1        S0002   37    Male             Python              9
# 2        S0003   32    Male              UI/UX             15
# 3        S0004   28  Female  Digital Marketing              7
# 4        S0005   25  Female  Digital Marketing              5
# ..         ...  ...     ...                ...            ...
# 195      S0196   19  Female             Python              3
# 196      S0197   38  Female              UI/UX              7
# 197      S0198   29  Female              UI/UX              3
# 198      S0199   23   Other  Digital Marketing             23
# 199      S0200   21   Other              UI/UX             24
#
#      avg_session_duration  quiz_attempts  assignments_submitted  \
# 0                  108.13              7                      5
# 1                   59.51              3                      1
# ...

# %%
# checking for unique value in course_type column
data['course_type'].unique()
# Out:
# array(['UI/UX', 'Python', 'Digital Marketing'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
#encoding the object into int type
data['course_type']=le.fit_transform(data['course_type'])

# %%
data['course_type']
# Out:
# 0      2
# 1      1
# 2      2
# 3      0
# 4      0
#       ..
# 195    1
# 196    2
# 197    2
# 198    0
# 199    2
# Name: course_type, Length: 200, dtype: int64

# %%
data
# Out:
#     student_id  age  gender  course_type  session_count  avg_session_duration  \
# 0        S0001   24    Male            2             11                108.13
# 1        S0002   37    Male            1              9                 59.51
# 2        S0003   32    Male            2             15                 81.77
# 3        S0004   28  Female            0              7                 24.82
# 4        S0005   25  Female            0              5                 27.11
# ..         ...  ...     ...          ...            ...                   ...
# 195      S0196   19  Female            1              3                113.94
# 196      S0197   38  Female            2              7                 22.64
# 197      S0198   29  Female            2              3                 72.42
# 198      S0199   23   Other            0             23                 63.18
# 199      S0200   21   Other            2             24                 75.32
#
# ...

# %%
# checking for unique value in gender column
data['gender'].unique()
# Out:
# array(['Male', 'Female', 'Other'], dtype=object)

# %%
#encoding the object into int type
data['gender']=le.fit_transform(data['gender'])

# %%
data
# Out:
#     student_id  age  gender  course_type  session_count  avg_session_duration  \
# 0        S0001   24       1            2             11                108.13
# 1        S0002   37       1            1              9                 59.51
# 2        S0003   32       1            2             15                 81.77
# 3        S0004   28       0            0              7                 24.82
# 4        S0005   25       0            0              5                 27.11
# ..         ...  ...     ...          ...            ...                   ...
# 195      S0196   19       0            1              3                113.94
# 196      S0197   38       0            2              7                 22.64
# 197      S0198   29       0            2              3                 72.42
# 198      S0199   23       2            0             23                 63.18
# 199      S0200   21       2            2             24                 75.32
#
# ...

# %%
data.dtypes
# Out:
# student_id                object
# age                        int64
# gender                     int64
# course_type                int64
# session_count              int64
# avg_session_duration     float64
# quiz_attempts              int64
# assignments_submitted      int64
# satisfaction_rating        int64
# dropout                    int64
# dtype: object

# %%
# dropping the student_id column
data.drop(["student_id"],axis=1,inplace=True)

# %%
data
# Out:
#      age  gender  course_type  session_count  avg_session_duration  \
# 0     24       1            2             11                108.13
# 1     37       1            1              9                 59.51
# 2     32       1            2             15                 81.77
# 3     28       0            0              7                 24.82
# 4     25       0            0              5                 27.11
# ..   ...     ...          ...            ...                   ...
# 195   19       0            1              3                113.94
# 196   38       0            2              7                 22.64
# 197   29       0            2              3                 72.42
# 198   23       2            0             23                 63.18
# 199   21       2            2             24                 75.32
#
#      quiz_attempts  assignments_submitted  satisfaction_rating  dropout
# 0                7                      5                    5        0
# ...

# %%
#checking for null values
data.isnull().sum()
# Out:
# age                      0
# gender                   0
# course_type              0
# session_count            0
# avg_session_duration     0
# quiz_attempts            0
# assignments_submitted    0
# satisfaction_rating      0
# dropout                  0
# dtype: int64

# %%
data.describe()
# Out:
#               age      gender  course_type  session_count  \
# count  200.000000  200.000000    200.00000     200.000000
# mean    27.850000    0.720000      0.90500      14.415000
# std      6.422127    0.673698      0.85418       8.898804
# min     18.000000    0.000000      0.00000       0.000000
# 25%     22.000000    0.000000      0.00000       6.750000
# 50%     27.500000    1.000000      1.00000      15.000000
# 75%     33.000000    1.000000      2.00000      22.000000
# max     39.000000    2.000000      2.00000      29.000000
#
#        avg_session_duration  quiz_attempts  assignments_submitted  \
# count            200.000000     200.000000             200.000000
# mean              59.160200       4.320000               2.380000
# std               31.797223       2.865073               1.720582
# min                7.310000       0.000000               0.000000
# 25%               30.850000       2.000000               1.000000
# ...

# %%
# assigning the columns for x and y variable
x=data.drop(["dropout"],axis=1)
y=data["dropout"]

# %%
# splitting the dataset
from sklearn.model_selection import train_test_split
xtrian,xtest,ytrain,ytest=train_test_split(x,y,random_state=1,test_size=0.3)

# %%
import tensorflow as tf

# %%
from tensorflow import keras

# %%
# creating the model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=64, activation='relu', input_shape=(8,)),
    tf.keras.layers.Dense(units=32, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(units=32, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(units=32, activation='relu'),
    tf.keras.layers.Dense(units=1) # Output layer for linear regression (no activation)
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compile the model
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %%
# fitting the model on the train dataset
model.fit(xtrian,ytrain,epochs=50,batch_size=32,validation_data=(xtest,ytest))
# Out:
# Epoch 1/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - loss: 88.7647 - mae: 6.8216 - val_loss: 3.1689 - val_mae: 1.4241
# Epoch 2/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 42.0679 - mae: 4.9888 - val_loss: 2.0355 - val_mae: 1.1757
# Epoch 3/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 30.9471 - mae: 3.9770 - val_loss: 1.3629 - val_mae: 0.9951
# Epoch 4/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 15.0198 - mae: 2.8459 - val_loss: 1.0063 - val_mae: 0.8718
# Epoch 5/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 7.1866 - mae: 2.1120 - val_loss: 0.7001 - val_mae: 0.6882
# Epoch 6/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 7.0139 - mae: 1.8761 - val_loss: 0.4410 - val_mae: 0.5312
# Epoch 7/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 3.9931 - mae: 1.4576 - val_loss: 0.3332 - val_mae: 0.4819
# Epoch 8/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 6.5238 - mae: 1.7714 - val_loss: 0.3219 - val_mae: 0.4796
# Epoch 9/50
# ...

# %%
from sklearn.metrics import r2_score, mean_squared_error

predictions = model.predict(xtest)
r2 = r2_score(ytest, predictions)
mse = mean_squared_error(ytest, predictions)

# Print the results
print(f"R-squared: {r2}")
print(f"Mean Squared Error: {mse}")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 532ms/step
# R-squared: -0.13262724876403809
# Mean Squared Error: 0.2818983793258667
